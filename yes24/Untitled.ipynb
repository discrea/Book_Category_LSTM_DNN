# %%
import pandas as pd

df = pd.read_csv('../data/yes24_new_book_test_data.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                       Title Medium_category  \
# 0             0             0             카밧진 박사의 부모 마음공부           가정 살림
# 1             1             1                슬기로운 미니멀 라이프           가정 살림
# 2             2             2     AI 세대에게 딱 맞는 자녀교육을 세팅하라           가정 살림
# 3             3             3             초등 공부는 문해력이 전부다           가정 살림
# 4             4             4                 개념연결 유아수학사전           가정 살림
# ..          ...           ...                         ...             ...
# 417         418           473          오전 9시에서 10시 30분 사이             청소년
# 418         419           474         우리는 동물을 어떻게 대해야 하는가           사회 정치
# 419         420           475                     나도향을 읽다             청소년
# 420         421           476        10대, 고전에서 길을 묻다 : 자연             청소년
# 421         422           477  소녀의 소녀에 의한 소녀를 위한 사회운동 안내서             청소년
#
#     Small_category                                       Introduction
# ...

# %%
cat = ['가정 살림', '건강 취미', '경제 경영', '국어 외국어 사전', '만화/라이트노벨', 
       '사회 정치', '소설/시/희곡', '수험서 자격증', '어린이', '유아', '인문', '청소년']

# %%
df['Medium_category'].isin(cat)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 417    True
# 418    True
# 419    True
# 420    True
# 421    True
# Name: Medium_category, Length: 422, dtype: bool

# %%
df = df[df['Medium_category'].isin(cat)]
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                       Title Medium_category  \
# 0             0             0             카밧진 박사의 부모 마음공부           가정 살림
# 1             1             1                슬기로운 미니멀 라이프           가정 살림
# 2             2             2     AI 세대에게 딱 맞는 자녀교육을 세팅하라           가정 살림
# 3             3             3             초등 공부는 문해력이 전부다           가정 살림
# 4             4             4                 개념연결 유아수학사전           가정 살림
# ..          ...           ...                         ...             ...
# 417         418           473          오전 9시에서 10시 30분 사이             청소년
# 418         419           474         우리는 동물을 어떻게 대해야 하는가           사회 정치
# 419         420           475                     나도향을 읽다             청소년
# 420         421           476        10대, 고전에서 길을 묻다 : 자연             청소년
# 421         422           477  소녀의 소녀에 의한 소녀를 위한 사회운동 안내서             청소년
#
#     Small_category                                       Introduction
# ...

# %%
df.to_csv('../data/yes24_new_book_test_data.csv')

# %%
# this note is test for commit new update
